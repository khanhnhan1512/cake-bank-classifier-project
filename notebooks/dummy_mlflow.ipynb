# %%
import mlflow
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from mlflow.pytorch import autolog
# Enable autologging
autolog()

# Create synthetic data
X = torch.randn(1000, 784)
y = torch.randint(0, 10, (1000,))
train_loader = DataLoader(TensorDataset(X, y), batch_size=32, shuffle=True)

# Your existing PyTorch code works unchanged
model = nn.Sequential(nn.Linear(784, 128), nn.ReLU(), nn.Linear(128, 10))
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# Training loop - metrics, parameters, and models logged automatically
for epoch in range(10):
    for data, target in train_loader:
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

# %%
import mlflow
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader

from mlflow.pytorch import autolog
# Enable autologging
autolog()

# Define model
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(28 * 28, 512),
            nn.ReLU(),
            nn.Linear(512, 10),
        )

    def forward(self, x):
        x = self.flatten(x)
        return self.linear_relu_stack(x)


# Training parameters
params = {
    "epochs": 5,
    "learning_rate": 1e-3,
    "batch_size": 64,
}

# Training with MLflow logging
    # Log parameters

# Initialize model and optimizer
model = NeuralNetwork()
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=params["learning_rate"])

# Training loop
for epoch in range(params["epochs"]):
    model.train()
    train_loss = 0
    correct = 0
    total = 0

    for data, target in train_loader:
        optimizer.zero_grad()
        output = model(data)
        loss = loss_fn(output, target)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = output.max(1)
        total += target.size(0)
        correct += predicted.eq(target).sum().item()

    # Log metrics per epoch
    avg_loss = train_loss / len(train_loader)
    accuracy = 100.0 * correct / total

# %%
import mlflow
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# Create data and model
X = torch.randn(1000, 784)
y = torch.randint(0, 10, (1000,))
train_loader = DataLoader(TensorDataset(X, y), batch_size=32, shuffle=True)

model = nn.Sequential(nn.Linear(784, 128), nn.ReLU(), nn.Linear(128, 10))
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# Enable system metrics logging
mlflow.enable_system_metrics_logging()

with mlflow.start_run():
    mlflow.log_params({"learning_rate": 0.001, "batch_size": 32, "epochs": 10})

    # Training loop - system metrics logged automatically
    for epoch in range(10):
        for data, target in train_loader:
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()

        mlflow.log_metric("loss", loss.item(), step=epoch)

    mlflow.pytorch.log_model(model, name="model")
# Out:
# 2025/12/25 14:21:19 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:21:19 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:21:25 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/12/25 14:21:25 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:21:25 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %%
import mlflow
import torch
import torch.nn as nn
from mlflow.models import infer_signature

model = nn.Sequential(nn.Linear(10, 50), nn.ReLU(), nn.Linear(50, 1))

# Create sample input and output for signature
input_example = torch.randn(1, 10)
predictions = model(input_example)

# Infer signature from input/output
signature = infer_signature(input_example.numpy(), predictions.detach().numpy())

with mlflow.start_run():
    # Log model with signature and input example
    mlflow.pytorch.log_model(
        model,
        name="pytorch_model",
        signature=signature,
        input_example=input_example.numpy(),
    )
# Out:
# 2025/12/25 14:21:25 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:21:25 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:21:30 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/12/25 14:21:30 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:21:30 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %%
import mlflow
import torch
import torch.nn as nn
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split


# Helper function to prepare data
def prepare_data(df):
    X = torch.tensor(df.iloc[:, :-1].values, dtype=torch.float32)
    y = torch.tensor(df.iloc[:, -1].values, dtype=torch.long)
    return X, y


# Helper function to compute accuracy
def compute_accuracy(model, X, y):
    with torch.no_grad():
        outputs = model(X)
        _, predicted = torch.max(outputs, 1)
        accuracy = (predicted == y).sum().item() / y.size(0)
    return accuracy


# Define a basic PyTorch classifier
class IrisClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super().__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x


# Load Iris dataset and prepare the DataFrame
iris = load_iris()
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
iris_df["target"] = iris.target

# Split into training and testing datasets
train_df, test_df = train_test_split(iris_df, test_size=0.2, random_state=42)

# Prepare training data
train_dataset = mlflow.data.from_pandas(train_df, name="iris_train")
X_train, y_train = prepare_data(train_dataset.df)

# Initialize model
input_size = X_train.shape[1]
hidden_size = 16
output_size = len(iris.target_names)
model = IrisClassifier(input_size, hidden_size, output_size)

# Training configuration
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

with mlflow.start_run() as run:
    # Log parameters once at the start
    mlflow.log_params(
        {
            "n_layers": 3,
            "activation": "ReLU",
            "criterion": "CrossEntropyLoss",
            "optimizer": "Adam",
            "learning_rate": 0.01,
        }
    )

    for epoch in range(101):
        # Training step
        out = model(X_train)
        loss = criterion(out, y_train)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Log a checkpoint every 10 epochs
        if epoch % 10 == 0:
            # Log model checkpoint with step parameter
            model_info = mlflow.pytorch.log_model(
                pytorch_model=model,
                name=f"iris-checkpoint-{epoch}",
                step=epoch,
                input_example=X_train[:5].numpy(),
            )

            # Log metrics linked to this checkpoint and dataset
            accuracy = compute_accuracy(model, X_train, y_train)
            mlflow.log_metric(
                key="train_accuracy",
                value=accuracy,
                step=epoch,
                model_id=model_info.model_id,
                dataset=train_dataset,
            )

# Search and rank checkpoints by performance
ranked_checkpoints = mlflow.search_logged_models(
    filter_string=f"source_run_id='{run.info.run_id}'",
    order_by=[{"field_name": "metrics.train_accuracy", "ascending": False}],
    output_format="list",
)

best_checkpoint = ranked_checkpoints[0]
print(f"Best checkpoint: {best_checkpoint.name}")
print(f"Accuracy: {best_checkpoint.metrics[0].value}")
# Out:
# 2025/12/25 17:08:51 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 17:08:51 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 17:08:56 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# /home/nhatminh/Desktop/cake-bank-classifier-project/.venv/lib/python3.10/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2025/12/25 17:09:00 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/12/25 17:09:05 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/12/25 17:09:10 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/12/25 17:09:15 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/12/25 17:09:20 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/12/25 17:09:25 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/12/25 17:09:30 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/12/25 17:09:34 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/12/25 17:09:39 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/12/25 17:09:44 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# 2025/12/25 17:09:44 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 17:09:44 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# Best checkpoint: iris-checkpoint-100
# Accuracy: 0.9833333333333333

# %%
model.parameters
# Out:
# <bound method Module.parameters of IrisClassifier(
#   (fc1): Linear(in_features=4, out_features=16, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=16, out_features=3, bias=True)
# )>

# %%
# Load as PyTorch model
model_uri = "runs:/28da8efc32434dd2a85a78281e3b991b/pytorch_model"
loaded_model = mlflow.pytorch.load_model(model_uri)

# Make predictions
input_tensor = torch.randn(5, 10)
predictions = loaded_model(input_tensor)

# Load as PyFunc for generic inference
pyfunc_model = mlflow.pyfunc.load_model(model_uri)
predictions = pyfunc_model.predict(input_tensor.numpy())
# Out:
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts: 100%|██████████| 8/8 [00:00<00:00, 490.63it/s]
# Downloading artifacts:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading artifacts: 100%|██████████| 8/8 [00:00<00:00, 782.74it/s]

# %%
import mlflow
import optuna
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset

# Create synthetic dataset for demonstration
input_size = 784  # e.g., flattened 28x28 images
output_size = 10  # e.g., 10 classes

X_train = torch.randn(1000, input_size)
y_train = torch.randint(0, output_size, (1000,))
X_val = torch.randn(200, input_size)
y_val = torch.randint(0, output_size, (200,))

train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=32, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val, y_val), batch_size=32)


def train_and_evaluate(model, optimizer, train_loader, val_loader, epochs=5):
    """Simple training loop for demonstration."""
    criterion = nn.CrossEntropyLoss()

    for epoch in range(epochs):
        model.train()
        for data, target in train_loader:
            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()

    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for data, target in val_loader:
            output = model(data)
            val_loss += criterion(output, target).item()

    return val_loss / len(val_loader)


def objective(trial):
    """Optuna objective for hyperparameter tuning."""

    with mlflow.start_run(nested=True):
        # Define hyperparameter search space
        params = {
            "learning_rate": trial.suggest_float("learning_rate", 1e-5, 1e-1, log=True),
            "hidden_size": trial.suggest_int("hidden_size", 32, 512),
            "dropout": trial.suggest_float("dropout", 0.1, 0.5),
        }

        # Log parameters
        mlflow.log_params(params)

        # Create model
        model = nn.Sequential(
            nn.Linear(input_size, params["hidden_size"]),
            nn.ReLU(),
            nn.Dropout(params["dropout"]),
            nn.Linear(params["hidden_size"], output_size),
        )

        # Train model
        optimizer = optim.Adam(model.parameters(), lr=params["learning_rate"])
        val_loss = train_and_evaluate(model, optimizer, train_loader, val_loader)

        # Log validation loss
        mlflow.log_metric("val_loss", val_loss)

        return val_loss


# Run optimization
with mlflow.start_run(run_name="PyTorch HPO"):
    study = optuna.create_study(direction="minimize")
    study.optimize(objective, n_trials=50)

    # Log best parameters
    mlflow.log_params({f"best_{k}": v for k, v in study.best_params.items()})
    mlflow.log_metric("best_val_loss", study.best_value)
# Out:
# 2025/12/25 14:22:21 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:21 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# [I 2025-12-25 14:22:21,781] A new study created in memory with name: no-name-f2207276-ca7f-449e-a705-f37c3949c6b4
# 2025/12/25 14:22:21 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:21 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:22 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:22 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:22,242] Trial 0 finished with value: 3.75914124080113 and parameters: {'learning_rate': 0.003632361855829157, 'hidden_size': 119, 'dropout': 0.4043751208515539}. Best is trial 0 with value: 3.75914124080113.
# 2025/12/25 14:22:22 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:22 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:23 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:23 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:23,045] Trial 1 finished with value: 2.490492480141776 and parameters: {'learning_rate': 0.00041930315438059, 'hidden_size': 500, 'dropout': 0.10324275129944774}. Best is trial 1 with value: 2.490492480141776.
# 2025/12/25 14:22:23 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:23 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:23 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:23 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:23,696] Trial 2 finished with value: 3.412219524383545 and parameters: {'learning_rate': 0.0021107107790526705, 'hidden_size': 341, 'dropout': 0.37685049092240097}. Best is trial 1 with value: 2.490492480141776.
# 2025/12/25 14:22:23 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:23 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:24 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:24 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:24,106] Trial 3 finished with value: 2.330108710697719 and parameters: {'learning_rate': 0.00041520256399664186, 'hidden_size': 47, 'dropout': 0.18438229468106915}. Best is trial 3 with value: 2.330108710697719.
# 2025/12/25 14:22:24 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:24 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:25 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:25 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:25,020] Trial 4 finished with value: 2.3085996082850864 and parameters: {'learning_rate': 4.3709067069020616e-05, 'hidden_size': 358, 'dropout': 0.40765967185707974}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:25 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:25 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:25 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:25 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:25,462] Trial 5 finished with value: 2.3431945187704906 and parameters: {'learning_rate': 0.00029687596295107087, 'hidden_size': 103, 'dropout': 0.1975792952546149}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:25 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:25 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:26 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:26 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:26,097] Trial 6 finished with value: 25.30355725969587 and parameters: {'learning_rate': 0.014166014469466831, 'hidden_size': 361, 'dropout': 0.23365511885217818}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:26 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:26 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:26 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:26 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:26,611] Trial 7 finished with value: 2.323551756995065 and parameters: {'learning_rate': 5.5779501351647943e-05, 'hidden_size': 180, 'dropout': 0.20550917810645203}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:26 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:26 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:27 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:27 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:27,146] Trial 8 finished with value: 2.3395841462271556 and parameters: {'learning_rate': 1.1795433984158738e-05, 'hidden_size': 200, 'dropout': 0.4874456184085191}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:27 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:27 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:27 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:27 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:27,744] Trial 9 finished with value: 3.6653975418635776 and parameters: {'learning_rate': 0.0028007150967554314, 'hidden_size': 268, 'dropout': 0.15066957408593243}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:27 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:27 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:28 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:28 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:28,480] Trial 10 finished with value: 1150.277587890625 and parameters: {'learning_rate': 0.0916857400161416, 'hidden_size': 441, 'dropout': 0.3099598191366253}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:28 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:28 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:29 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:29 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:29,037] Trial 11 finished with value: 2.345341784613473 and parameters: {'learning_rate': 1.6020245859890812e-05, 'hidden_size': 227, 'dropout': 0.2922947100722112}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:29 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:29 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:29 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:29 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:29,677] Trial 12 finished with value: 2.323162181036813 and parameters: {'learning_rate': 5.459644827378184e-05, 'hidden_size': 341, 'dropout': 0.4989692829145045}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:29 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:29 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:30 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:30 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:30,327] Trial 13 finished with value: 2.3282534394945418 and parameters: {'learning_rate': 8.601842582988842e-05, 'hidden_size': 357, 'dropout': 0.4942308581051653}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:30 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:30 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:31 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:31 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:31,031] Trial 14 finished with value: 2.331439597266061 and parameters: {'learning_rate': 7.193060525931494e-05, 'hidden_size': 419, 'dropout': 0.43547787942855354}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:31 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:31 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:31 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:31 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:31,648] Trial 15 finished with value: 2.3150058814457486 and parameters: {'learning_rate': 2.9718469952485126e-05, 'hidden_size': 320, 'dropout': 0.4442965750392667}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:31 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:31 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:32 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:32 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:32,263] Trial 16 finished with value: 2.3279573236192976 and parameters: {'learning_rate': 1.9100921843896902e-05, 'hidden_size': 296, 'dropout': 0.35599423752029885}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:32 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:32 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:32 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:32 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:32,975] Trial 17 finished with value: 2.3109002453940257 and parameters: {'learning_rate': 0.0001373366815099091, 'hidden_size': 435, 'dropout': 0.4231517173330826}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:32 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:32 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:33 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:33 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:33,744] Trial 18 finished with value: 2.3355345726013184 and parameters: {'learning_rate': 0.00016645694482764496, 'hidden_size': 512, 'dropout': 0.3158436247505557}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:33 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:33 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:34 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:34 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:34,443] Trial 19 finished with value: 2.3386594908578053 and parameters: {'learning_rate': 0.00017427408280274985, 'hidden_size': 427, 'dropout': 0.440781591267401}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:34 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:34 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:35 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:35 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:35,138] Trial 20 finished with value: 2.85348037311009 and parameters: {'learning_rate': 0.0009548861370394376, 'hidden_size': 390, 'dropout': 0.38094465880561723}. Best is trial 4 with value: 2.3085996082850864.
# 2025/12/25 14:22:35 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:35 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:35 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:35 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:35,895] Trial 21 finished with value: 2.3012897287096297 and parameters: {'learning_rate': 3.135578041871922e-05, 'hidden_size': 463, 'dropout': 0.4409009330925848}. Best is trial 21 with value: 2.3012897287096297.
# 2025/12/25 14:22:35 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:35 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:36 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:36 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:36,629] Trial 22 finished with value: 2.329972403390067 and parameters: {'learning_rate': 3.430179940379231e-05, 'hidden_size': 467, 'dropout': 0.4145047116302627}. Best is trial 21 with value: 2.3012897287096297.
# 2025/12/25 14:22:36 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:36 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:37 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:37 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:37,306] Trial 23 finished with value: 2.2920985903058733 and parameters: {'learning_rate': 0.00013529120391055609, 'hidden_size': 395, 'dropout': 0.34935101647535177}. Best is trial 23 with value: 2.2920985903058733.
# 2025/12/25 14:22:37 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:37 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:37 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:37 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:37,982] Trial 24 finished with value: 2.2888998985290527 and parameters: {'learning_rate': 1.0084343020261686e-05, 'hidden_size': 388, 'dropout': 0.3392070277282863}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:38 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:38 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:38 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:38 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:38,895] Trial 25 finished with value: 2.309371198926653 and parameters: {'learning_rate': 1.464365224656537e-05, 'hidden_size': 470, 'dropout': 0.272728766053442}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:38 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:38 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:39 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:39 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:39,568] Trial 26 finished with value: 2.3211188316345215 and parameters: {'learning_rate': 2.6540199435033033e-05, 'hidden_size': 391, 'dropout': 0.3456555279433462}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:39 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:39 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:40 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:40 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:40,142] Trial 27 finished with value: 2.336130040032523 and parameters: {'learning_rate': 9.91082034062392e-05, 'hidden_size': 264, 'dropout': 0.2606732660159089}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:40 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:40 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:40 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:40 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:40,885] Trial 28 finished with value: 2.3197173731667653 and parameters: {'learning_rate': 1.353243532548493e-05, 'hidden_size': 401, 'dropout': 0.33847736930947747}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:40 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:40 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:41 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:41 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:41,632] Trial 29 finished with value: 2.744894504547119 and parameters: {'learning_rate': 0.0008208603127857203, 'hidden_size': 477, 'dropout': 0.3848528059780389}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:41 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:41 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:42 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:42 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:42,459] Trial 30 finished with value: 19.165343148367747 and parameters: {'learning_rate': 0.011050959516030818, 'hidden_size': 455, 'dropout': 0.4540571357139861}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:42 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:42 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:43 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:43 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:43,131] Trial 31 finished with value: 2.3071071079799106 and parameters: {'learning_rate': 4.024114917585869e-05, 'hidden_size': 386, 'dropout': 0.39733136031284183}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:43 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:43 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:43 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:43 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:43,758] Trial 32 finished with value: 2.3584369591304233 and parameters: {'learning_rate': 2.6205228764903614e-05, 'hidden_size': 303, 'dropout': 0.46335725015721463}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:43 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:43 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:44 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:44 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:44,435] Trial 33 finished with value: 2.332089730671474 and parameters: {'learning_rate': 1.006913899853731e-05, 'hidden_size': 394, 'dropout': 0.3699107842772608}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:44 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:44 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:45 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:45 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:45,176] Trial 34 finished with value: 2.3579537527901784 and parameters: {'learning_rate': 0.00021477157774976583, 'hidden_size': 491, 'dropout': 0.3249684806119034}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:45 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:45 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:45 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:45 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:45,843] Trial 35 finished with value: 2.5615903309413364 and parameters: {'learning_rate': 0.0006266533441046083, 'hidden_size': 377, 'dropout': 0.3929525641804704}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:45 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:45 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:46 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:46 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:46,478] Trial 36 finished with value: 3.149949925286429 and parameters: {'learning_rate': 0.0016056203540576995, 'hidden_size': 320, 'dropout': 0.35642908314870475}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:46 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:46 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:47 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:47 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:47,170] Trial 37 finished with value: 2.34991717338562 and parameters: {'learning_rate': 0.0003434040822877004, 'hidden_size': 415, 'dropout': 0.3965027214911305}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:47 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:47 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:47 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:47 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:47,883] Trial 38 finished with value: 2.302365745816912 and parameters: {'learning_rate': 3.712329162126518e-05, 'hidden_size': 446, 'dropout': 0.47470204216371337}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:47 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:47 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:48 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:48 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:48,643] Trial 39 finished with value: 2.3317817619868686 and parameters: {'learning_rate': 2.204675726255086e-05, 'hidden_size': 493, 'dropout': 0.4695856017632731}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:48 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:48 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:49 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:49 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:49,063] Trial 40 finished with value: 2.3244216782706126 and parameters: {'learning_rate': 0.00010747974090034305, 'hidden_size': 50, 'dropout': 0.47306025441657146}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:49 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:49 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:49 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:49 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:49,838] Trial 41 finished with value: 2.304199116570609 and parameters: {'learning_rate': 4.0356671183738224e-05, 'hidden_size': 440, 'dropout': 0.4184294111753122}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:49 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:49 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:50 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:50 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:50,592] Trial 42 finished with value: 2.349664177213396 and parameters: {'learning_rate': 5.059004761867681e-05, 'hidden_size': 454, 'dropout': 0.4209542108329657}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:50 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:50 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:51 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:51 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:51,313] Trial 43 finished with value: 2.306039708001273 and parameters: {'learning_rate': 6.87568387464313e-05, 'hidden_size': 445, 'dropout': 0.2924414231702963}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:51 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:51 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:51 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:51 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:51,995] Trial 44 finished with value: 2.315201452800206 and parameters: {'learning_rate': 4.654770840790632e-05, 'hidden_size': 364, 'dropout': 0.47596362427537403}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:52 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:52 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:52 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:52 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:52,707] Trial 45 finished with value: 2.339207240513393 and parameters: {'learning_rate': 1.9472436653001892e-05, 'hidden_size': 413, 'dropout': 0.12994525007620897}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:52 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:52 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:53 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:53 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:53,195] Trial 46 finished with value: 2.3223939623151506 and parameters: {'learning_rate': 1.0208560414418479e-05, 'hidden_size': 146, 'dropout': 0.4305739267287919}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:53 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:53 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:53 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:53 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:53,864] Trial 47 finished with value: 5.413165705544608 and parameters: {'learning_rate': 0.005836694571748719, 'hidden_size': 342, 'dropout': 0.3653928577001362}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:53 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:53 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:54 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:54 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:54,598] Trial 48 finished with value: 2.3083376543862477 and parameters: {'learning_rate': 3.775856629734002e-05, 'hidden_size': 477, 'dropout': 0.23474142106683704}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:54 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:54 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:55 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:55 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [I 2025-12-25 14:22:55,312] Trial 49 finished with value: 2.324343511036464 and parameters: {'learning_rate': 0.0002309520125756298, 'hidden_size': 438, 'dropout': 0.4060170157768378}. Best is trial 24 with value: 2.2888998985290527.
# 2025/12/25 14:22:55 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:55 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %%
import mlflow
import torch.nn as nn
from mlflow import MlflowClient

client = MlflowClient()

with mlflow.start_run():
    # Create a simple model for demonstration
    model = nn.Sequential(
        nn.Conv2d(3, 32, 3),
        nn.ReLU(),
        nn.MaxPool2d(2),
        nn.Flatten(),
        nn.Linear(32 * 15 * 15, 10),
    )

    # Log model to registry
    model_info = mlflow.pytorch.log_model(
        model, name="pytorch_model", registered_model_name="ImageClassifier"
    )

    # Tag for tracking
    mlflow.set_tags(
        {"model_type": "cnn", "dataset": "imagenet", "framework": "pytorch"}
    )

# Set alias for production deployment
client.set_registered_model_alias(
    name="ImageClassifier",
    alias="champion",
    version=model_info.registered_model_version,
)
# Out:
# 2025/12/25 14:22:55 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# 2025/12/25 14:22:55 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# 2025/12/25 14:22:59 WARNING mlflow.utils.environment: Failed to resolve installed pip version. ``pip`` will be added to conda.yaml environment spec without a version specifier.
# Registered model 'ImageClassifier' already exists. Creating a new version of this model...
# Created version '2' of model 'ImageClassifier'.
# 2025/12/25 14:22:59 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2025/12/25 14:22:59 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!

# %%
import mlflow
import torch
import torch.nn as nn
import torch.distributed as dist
from torch.nn.parallel import DistributedDataParallel as DDP
from torch.utils.data import DataLoader, TensorDataset

# Create synthetic dataset
X_train = torch.randn(1000, 784)
y_train = torch.randint(0, 10, (1000,))
train_dataset = TensorDataset(X_train, y_train)

# Simple model
model = nn.Sequential(nn.Linear(784, 128), nn.ReLU(), nn.Linear(128, 10))


def train_epoch(model, train_loader):
    """Simple training epoch for demonstration."""
    model.train()
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    total_loss = 0

    for data, target in train_loader:
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    return total_loss / len(train_loader)


def train_distributed():
    # Initialize distributed training
    dist.init_process_group(backend="nccl")
    rank = dist.get_rank()

    # Wrap model with DDP
    model_ddp = DDP(model.to(rank), device_ids=[rank])

    # Create distributed sampler
    from torch.utils.data.distributed import DistributedSampler

    sampler = DistributedSampler(
        train_dataset, num_replicas=dist.get_world_size(), rank=rank
    )
    train_loader = DataLoader(train_dataset, batch_size=32, sampler=sampler)

    # Only log from rank 0
    if rank == 0:
        mlflow.start_run()
        mlflow.log_params({"world_size": dist.get_world_size(), "backend": "nccl"})

    # Training loop
    epochs = 10
    for epoch in range(epochs):
        sampler.set_epoch(epoch)  # Shuffle data differently each epoch
        train_loss = train_epoch(model_ddp, train_loader)

        # Log metrics from rank 0 only
        if rank == 0:
            mlflow.log_metric("train_loss", train_loss, step=epoch)

    # Save model from rank 0
    if rank == 0:
        mlflow.pytorch.log_model(model, name="distributed_model")
        mlflow.end_run()
