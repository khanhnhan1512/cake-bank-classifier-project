# %% [markdown]
# Lộ trình tổng quan (Master Plan)
# Phase 1: Setup & Data Pipeline (Ngày 1)
#
# Thiết lập môi trường, cấu trúc thư mục.
#
# Viết class Dataset xử lý ảnh: Crop khuôn mặt (quan trọng nhất), Resize.
#
# Phase 2: Model Architecture (Ngày 2)
#
# Implement model: Sử dụng MobileNetV2 (để đảm bảo chạy được ngay) nhưng thiết kế code dạng module để dễ mở rộng.
#
# (Optional) Nếu Phase 1 & 2 làm nhanh, ta sẽ thử tích hợp kiến trúc MiniFASNet.
#
# Phase 3: Training Loop & Tuning (Ngày 3)
#
# Viết vòng lặp training.
#
# Implement các kỹ thuật Augmentation để chống overfit.
#
# Phase 4: Evaluation & Metrics (Ngày 4)
#
# Tính toán các chỉ số ISO (APCER, BPCER, AUC) như trong report.
#
# Viết script predict.py để chạy thử trên ảnh mới.
#
# Phase 5: Finalize Report & Submission (Ngày 5)
#
# Hoàn thiện bản báo cáo (chèn biểu đồ, hình ảnh).
#
# Review code lần cuối.

# %%
import pandas as pd
